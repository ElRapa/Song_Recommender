# %% [markdown]
# # Song recommender

# %%
import pandas as pd
import numpy as np
import scraping as sc
import helper_functions as hf
import data_handler as dh
import spotifyhandler as sh
import spotipy
import pickle
from tqdm.auto import tqdm
import modelling

from matplotlib import pyplot
from sklearn.metrics import silhouette_score

# %%
# Run Marker
update_bb_top100 = False
update_wiki_artist = False
update_song_list = False
update_audio_features = False
create_words_list = False

# %%
# Load existing files

# %%
#sc.recommend_song()

# %%
if update_wiki_artist:
    artist_Series = sc.load_or_scrape('wiki_artist')['artists']
    artist_list = list(artist_Series)

# %%
if update_song_list:
    song_list = sh.search_songs(artist_list)
    len(song_list)

# %%
if create_words_list:
    print('create words list')
    words_list = hf.txt_to_list('data/speeches.txt')
    len(words_list)

# %%
if create_words_list:    
    song_list_update = sh.search_songs(words_list)
    len(song_list_update)

# %%
## concat multiple csvs and concat it to original df
if update_audio_features:
    df_complete_update = dh.concat_csvs('audio_features_update',25)
    df_complete_update.shape
    dh.update_audiofeatures_csv(df_complete_update)

# %% [markdown]
# ### Load audiofeatures csv into df

# %%
df_audiofeatures = pd.read_csv('data/audio_features.csv')
print(df_audiofeatures.shape)
df_audiofeatures.head(3)
# Out:
# (275081, 20)
#           artists                               name  danceability  energy  \
# 0           Wings  Mull Of Kintyre - Remastered 1993         0.350   0.297
# 1  Ben Folds Five        Selfless, Cold and Composed         0.233   0.497
# 2     Jimmy Cliff                      Give And Take         0.833   0.559
#
#    key  loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# 0    2   -13.781     1       0.0265      0.000285            0.0000     0.123
# 1   11    -9.508     1       0.0322      0.361000            0.0288     0.076
# 2    2   -13.320     1       0.0688      0.087000            0.0000     0.333
#
#    valence    tempo            type                      id  \
# 0    0.423   90.603  audio_features  5yrgufPBA1PqSIOHZHrkYa
# 1    0.272  180.779  audio_features  43Fd2LMelrD0HU01n4g4cw
# 2    0.652  127.907  audio_features  2YYtbzCV6jKwemSv6JoI8R
#
#                                     uri  \
# 0  spotify:track:5yrgufPBA1PqSIOHZHrkYa
# 1  spotify:track:43Fd2LMelrD0HU01n4g4cw
# 2  spotify:track:2YYtbzCV6jKwemSv6JoI8R
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/5yrgufPBA1Pq...
# 1  https://api.spotify.com/v1/tracks/43Fd2LMelrD0...
# 2  https://api.spotify.com/v1/tracks/2YYtbzCV6jKw...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/5yrg...       282533
# 1  https://api.spotify.com/v1/audio-analysis/43Fd...       370347
# 2  https://api.spotify.com/v1/audio-analysis/2YYt...       133333
#
#    time_signature
# 0               3
# 1               3
# 2               4

# %% [markdown]
# ### Train scaler on audiofeatures df

# %%
# first strip of df of unessessary columns
X = modelling.to_feature_df(df_audiofeatures.iloc[:1000])

# fit scaler to df
scaler = modelling.fit_scaler(X)

# transform df
X_scaled = modelling.scale(X)

# %%
X_scaled
# Out:
#      danceability    energy       key  loudness      mode  speechiness  \
# 0       -1.452087 -1.500675 -0.921466 -1.350089  0.753258    -0.660208
# 1       -2.156935 -0.651813  1.571229 -0.379404  0.753258    -0.598323
# 2        1.457668 -0.388666 -0.921466 -1.245365  0.753258    -0.200957
# 3        0.813064  0.617235 -0.090568  0.905226 -1.327566    -0.143415
# 4        0.638358  0.914337 -1.475399  0.046761  0.753258    -0.563580
# ..            ...       ...       ...       ...       ...          ...
# 995      0.746796  0.001810 -0.090568 -0.318750  0.753258     0.354920
# 996      1.096208  1.275103  1.571229  0.859565 -1.327566    -0.321470
# 997     -0.114684  0.676656 -1.475399  0.097874  0.753258    -0.650436
# 998      0.337141  0.753053  1.017297  0.572653  0.753258    -0.356212
# 999      0.349190  0.120651 -0.921466 -1.062495  0.753258    -0.604837
#
#      acousticness  instrumentalness  liveness   valence     tempo  \
# 0       -0.864968         -0.383221 -0.430493 -0.407111 -1.106312
# 1        0.281052         -0.261619 -0.694848 -1.047714  2.070327
# 2       -0.589467         -0.383221  0.750671  0.564400  0.207800
# 3       -0.586608         -0.383221 -0.581794  1.480760 -0.422660
# 4       -0.208218         -0.383221 -0.811277  1.404397  0.217593
# ..            ...               ...       ...       ...       ...
# 995      0.678187         -0.383221  0.160089  0.908035  0.454636
# 996     -0.645702         -0.348176  0.683176  0.356522 -0.443197
# 997     -0.865603         -0.382638 -0.560983 -0.873775 -0.829568
# 998     -0.862823         -0.383221 -0.590793  0.759551 -0.883042
# 999      0.608291         -0.378112  0.784419  1.917728  0.171164
#
#      time_signature
# 0         -3.172432
# 1         -3.172432
# 2          0.174015
# 3          0.174015
# 4          0.174015
# ..              ...
# 995        0.174015
# 996        0.174015
# 997        0.174015
# 998        0.174015
# 999        0.174015
#
# [1000 rows x 12 columns]

# %% [markdown]
# ### Train Model on audiofeatures df

# %%
kmeans = modelling.train_kmeans(X_scaled, number_clusters=12)
len(kmeans.labels_)
# Out:
# 1000

# %%
# assign a cluster to each example
labels = kmeans.predict(X_scaled)
labels
# Out:
# array([ 2,  2,  1,  5,  1,  3,  5, 11, 11, 11,  8, 11,  3,  4,  5,  7,  1,
#         5,  9,  4,  1,  7,  6,  3,  4,  4,  3,  3,  4,  2,  4,  5,  4,  5,
#         5,  3,  0,  0,  9,  9,  7,  6,  6,  5,  7, 10, 11,  5,  3,  8, 10,
#         4, 10,  9,  4,  1, 11,  7,  5,  3,  4,  1,  5,  0,  7,  9,  5,  1,
#         5,  1,  5,  4,  9,  0, 10,  6,  8,  5,  5, 11,  5,  9,  4,  5, 10,
#         9,  9,  6,  1,  7,  7,  1,  1,  2,  1,  0,  3, 11,  0,  5,  8, 11,
#         6,  6,  5, 11,  0,  1, 11,  1,  3,  4,  7,  4,  1,  3,  2,  9,  3,
#         4,  4,  5,  4,  3,  0, 11, 10,  1,  3,  3,  5, 11,  6,  3,  1,  6,
#         5,  1,  4,  3,  6, 11,  7,  3,  1, 10,  1,  0,  1,  6,  5,  6,  3,
#         3,  7,  0, 11,  5,  1,  4,  1,  4,  5,  3, 10, 11,  3,  6,  6,  3,
#         3,  3,  2,  6,  6,  1,  6,  6,  5, 10,  4,  4,  9,  4,  6,  0,  4,
#         7,  8,  1, 11, 11,  2,  0,  3,  9,  5,  4,  9,  6,  4,  4,  4,  6,
#         9,  1,  5, 11,  3,  9,  1,  1,  3,  9,  9,  4,  6,  5,  2,  4,  6,
#         5,  5,  1,  9,  6,  9, 10, 10, 11,  5,  6, 11,  5,  1,  4,  2,  5,
#         4,  1,  2,  2,  0,  4,  3,  5,  8,  3,  3,  1,  6,  2,  5,  3,  4,
#         4,  4,  5,  4,  5,  9,  5,  8, 11,  3, 11, 11,  3,  5,  4,  0,  7,
#         0,  7,  6,  0,  5,  6, 11,  5,  0,  4,  6,  3,  4,  5,  3,  9,  4,
#         5,  6,  4,  5,  5,  7,  5,  9,  0,  9, 11,  3,  6, 11,  4,  8,  3,
#         0,  2,  6,  0,  4,  1,  9,  7,  4,  0,  7,  5,  3,  5,  1,  0,  4,
#         1,  7,  3,  1,  9,  1,  5,  3, 10,  6,  5,  4,  2,  5,  5, 10,  0,
#        11,  1,  5,  1,  2,  9,  3,  4,  0,  4,  2,  1,  4,  1,  1,  5,  5,
#         4,  3, 11,  3, 11,  5,  5,  0,  0,  1,  7, 10,  0,  9,  7,  7, 11,
#         3,  9, 10,  7,  5,  1,  5,  4,  1, 11,  3, 10,  5,  4,  8,  8,  5,
#         4,  7,  0,  3,  6,  5,  1,  1,  2,  3,  6,  5,  6,  1,  9, 11,  3,
#         5, 11,  6,  9,  5,  5, 10,  5,  4,  6,  2,  1,  4,  3, 11,  4,  5,
#         7,  4,  3,  1,  2, 10,  6,  7,  5, 11,  7, 10,  9,  5,  4,  1, 11,
#         5, 11,  6,  1,  2,  8,  0,  4,  7,  2,  6,  1,  1,  6,  6,  4,  8,
#        11,  5,  5,  6, 11,  8,  4,  9,  4, 10,  5,  1,  4,  3,  0,  5,  4,
#         4,  6,  3,  1,  3,  9,  5,  2,  5,  8, 11,  3,  3,  1,  3,  9,  1,
#         9,  4,  8,  6,  1, 11,  7,  4,  1,  0, 10,  5,  5,  4,  9,  5,  1,
#         5,  3,  0,  3,  0,  8,  0,  7,  5,  0,  7,  4,  5,  6, 11,  7,  0,
#         7, 11,  5,  1,  1,  4,  3,  6, 10,  1,  5,  1,  4,  1])

# %%
# retrieve unique clusters
clusters = np.unique(labels)
# create scatter plot for samples from each cluster
for cluster in clusters:
    # get row indexes for samples with this cluster
    row_ix = np.where(labels == cluster)
    # create scatter of these samples
    pyplot.scatter(X.to_numpy()[row_ix, 1], X.to_numpy()[row_ix, 2])
    # show the plot
pyplot.show()

# %%
clusters = kmeans.predict(X_scaled)
#clusters
pd.Series(clusters).value_counts().sort_index()
# Out:
# 0      72
# 1     126
# 2      43
# 3     103
# 4     139
# 5     150
# 6      82
# 7      64
# 8      34
# 9      58
# 10     47
# 11     82
# dtype: int64
